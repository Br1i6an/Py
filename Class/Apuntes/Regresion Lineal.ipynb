# %% [markdown]
# # Regresión Lineal

# %% [markdown]
# **APRENDIZAJE SUPERVISADO**
# **APRENDIZAJE BASADO EN MODELOS**
# Se corresponde con un **modelo lineal**
#
# Realiza predicciones computando una **suma ponderada de las características de entrada** y sumandole una constante conocida como
# **bias**
#
# Intenta predecir valores continuos

# %% [markdown]
# **FUNCIÓN HIPÓTESIS**
# Conjunto de datos->Función hipótesis() -> Modelo -> Predicción
# ## $h_{\theta}$(x)=$\theta_{0}$+$\theta_{1}$x

# %%
import matplotlib.pyplot as plt
plt.plot()
plt.xlim(0,10)
plt.ylim(0,10)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# **PARÁMETROS DEL MODELO**
# ## =$\theta_{0}$+$\theta_{1}$x

# %% [markdown]
# Bucar los parámetros $\theta_{0}$ y $\theta_{1}$ que generen la función hipótesis $h_{0}$ (x) que mejor se adapte al conjunto de datos de entrenamiento (x,y)
#
#
# Se minimiza una función de coste (J($\theta$)) para obtener los parámetros $\theta_{0}$ y $\theta_{1}$ óptimos

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 4))
plt.subplot(1,2,1)
plt.xlim(0,10)
plt.ylim(0,10)
plt.xlabel('x')
plt.xlabel('y')
plt.show()

# %% [markdown]
# **FUNCIÓN DE COSTE J($\theta$)**
#
# **Mean Square Error (MSE)**
# ## J($\theta$)=$\frac{1}{2}$$\sum_{i=1}^{m} (h_\theta (x^i) - y^i)^2$

# %%
import matplotlib.pyplot as plt
plt.plot()
plt.xlim(0,10)
plt.ylim(0,10)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# **FUNCIÓN DE OPTIMIZACIÓN: GRADIEN DESCENT**

# %% [markdown]
# Desmos
